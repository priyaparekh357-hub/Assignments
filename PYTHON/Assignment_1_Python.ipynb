# %%
# 1) What are the types of Applications?
Ans: Types of Applications (Software Applications) can be classified in several common ways. Here are the main types, explained simply:
1. Desktop Applications
2. Web Applications
3. Mobile Applications
4. Enterprise Applications
5. System Applications
6. Utility Applications
7. Embedded Applications
8. Cloud Applications

# %%
# 2) What is programing?
Ans: Python is a high-level, general-purpose programming language known for its simplicity, readability, and versatility

# %%
# 3) What is Python?
Ans: Python is an interpreted ,object, oriented, high level programming language with dynamic semantics.

# %%
# 4) Write a Python program to check if a number is positive, negative or zero.
num = int(input("Enter a number here: "))

if num > 0:
   print("It is a positive number")
elif num == 0:
   print("It is zero")
else:
   print("It is a nagative number")
# Out:
# Enter a number here: 1
# It is a positive number

# %%
# 5)Write a Python program to get the Factorial number of given numbers.

num = int(input("Enter a number: "))
factorial = 1

if num <0:
  print("factorial does not exist")
elif num == 0:
  print("The factorial is 1")
else:
  for i in range(1, num+1):
      factorial = factorial*i
  print("The factorial of", num, "is", factorial)
# Out:
# Enter a number: 5
# The factorial of 5 is 120

# %%
# 6) Write a Python program to get the Fibonacci series of given range.
# Ans:
num = int(input("Enter a number : "))
print("Fibonacci series :")
num1 = 0
num2 = 1
count =0
print(num1, end=" ")
print(num2, end=" ")
while count < num:
  result = num1 + num2
  print(result,end=" ")
  num1 = num2
  num2 = result
  count = count + 1
# Out:
# Enter a number : 6
# Fibonacci series :
# 0 1 1 2 3 5 8 13

# %%
#7) How memory is managed in Python?
- Ans: Python manages memory automatically through a combination of a private heap space, reference counting, and a generational garbage collector.
 Memory is generally divided into two areas:
 * Stack Memory: Used for function calls and local variables. Memory here is allocated statically and automatically freed when the function call ends.
 * Heap Memory: This is where the actual Python objects (e.g., lists, dictionaries, class instances, large data structures) reside. Allocation is dynamic and handled by the memory manager at runtime.

# %%
#8) What is the purpose continuing statement in python?
- Ans: The continue statement in Python is used to skip the rest of the current iteration of a loop and move on to the next iteration.

# %%
# 9) Write python program that swap two number with temp variable and without temp variable.

a = int(input("Enter a: "))
b = int(input("Enter b: "))

a,b = b,a
print("The value of a is "+str(a) +" and the value of b is "+str(b))
# Out:
# Enter a: 3
# Enter b: 4
# The value of a is 4 and the value of b is 3

# %%
# 10) Write a Python program to find whether a given number is even or odd, print out an appropriate message to the user.
number = int(input("Enter a number: "))

if number % 2 == 0:
    print(f"{number} is an even number.")
else:
    print(f"{number} is an odd number")
# Out:
# Enter a number: 216
# 216 is an even number.

# %%
# 11) Write a Python program to test whether a passed letter is a vowel or not.
# Ans:
letter = input("Enter a letter : ")
if letter in "aeiou":
  print("Passed Letter is Vowel")
else:
  print("Passed Letter is not Vowel")
# Out:
# Enter a letter : a
# Passed Letter is Vowel

# %%
# 12) Write a Python program to sum of three given integers. However, if two values are equal sum will be zero.
# Ans:
a = int(input("Enter first value: "))
b = int(input("Enter second value: "))
c = int(input("Enter third value: "))

if a == b or b == c or c == a:
    print("sum is : ",0)
else:
    print("sum is :", a+b+c)
# Out:
# Enter first value: 1
# Enter second value: 1
# Enter third value: 9
# sum is :  0

# %%
# 13) Write a Python program that will return true if the two given integer values are equal or their sum or difference is 5.
def test_numbers(a,b):

  if a == b or abs(a-b) == 5 or (a+b) == 5:
    return True
  else:
    return False

# %%
print(test_numbers(8,5))
print(test_numbers(2,7))
print(test_numbers(3,2))
print(test_numbers(2,2))
print(test_numbers(10,5))
print(test_numbers(7,3))
print(test_numbers(27,59))
# Out:
# False
# True
# True
# True
# True
# False
# False

# %%
# 14. Write a python program to sum of the first n positive integers.

n = int(input("Enter a number: "))

sum = (n * (n+1)) / 2

print("The sum of the first", n, "positive integers is", sum)
# Out:
# Enter a number: 2
# The sum of the first 2 positive integers is 3.0

# %%
#15. Write a Python program to calculate the length of a string.

string = "Hello world"
print(len(string))
# Out:
# 11

# %%
#16. Write a Python program to count the number of characters (character frequency) in a string

def freq (my_str):
    d1 = {}
    for i in my_str:
        keys = d1.keys()
        if i in d1:
            d1[i] += 1
        else:
            d1[i] = 1
    print(d1)

print(freq("programming"))
# Out:
# {'p': 1, 'r': 2, 'o': 1, 'g': 2, 'a': 1, 'm': 2, 'i': 1, 'n': 1}
# None

# %%
# 17) What are negative indexes and why are they used?
a = "Hello World"
print(a[-5:-1])
# Out:
# Worl

# %%
# 18) Write a Python program to count occurrences of a substring in a string.
x = " hello how r u "
substring = "hello"
count=x.count("hello")
print("number of sequence:,",count)
# Out:
# number of sequence:, 1

# %%
# 19) Write a Python program to count the occurrences of each word in a given sentence
text = input("Enter a string : ")
char = input("Enter a character: ")
count = 0

for letter in text:
  if char == letter:
    count = count + 1

print("The Numebr of occurrences of character in a string is : ", count)
# Out:
# Enter a string : hello paython
# Enter a character: a
# The Numebr of occurrences of character in a string is :  1

# %%
# 20) Write a Python program to get a single string from two given strings, separated by a space and swap the first two characters of each string.
x = input("enter a string :")
y = input("enter a second string :")
print(x,',',y)
x_new = y[0:2]+x[2:]
y_new = x[0:2]+y[2:]
print(x_new,',',y_new)
# Out:
# enter a string :abc
# enter a second string :xyz
# abc , xyz
# xyc , abz

# %%
# 21) Write a Python program to add 'in' at the end of a given string (length
# should be at least 3). If the given string already ends with 'ing' then
# add 'ly' instead if the string length of the given string is less than 3,
# leave it unchanged.
# sample input    expected output
# 'abc'               'abcing'
# 'string'            'stringly'

s = "string"
if len(s) > 2:
  if s.endswith('ing'):
      s += 'ly'
  else:
      s+= 'ing'
print(s)
# Out:
# stringly

# %%
# 22) Write a Python function to reverses a string if its length is a multiple of 4.
def reverse_string(str1):
  if len(str1) % 4 == 0:
    return ''.join(reversed(str1))
  return str1
print(reverse_string('abcd'))
print(reverse_string('python'))
# Out:
# dcba
# python

# %%
# 23) Write a Python program to get a string made of the first 2 and the last
# 2 chars from a given a string. If the string length is less than 2, return
# instead of the empty string.
x=input("enter a string :")
n=len(x)
if n>2:
  a=x[0:2]
  b=x[-2:]
  print(a+b)
else:
  print(' ')
# Out:
# enter a string :logical
# loal

# %%
# 24)  Write a Python function to insert a string in the middle of a string.
def insert_string_middle(str, word):
    return str[:2] + word + str[2:]
print(insert_string_middle('[[]]', 'python'))
print(insert_string_middle('{{}}', 'php'))
print(insert_string_middle('<<>>', 'HTML'))
# Out:
# [[python]]
# {{php}}
# <<HTML>>

# %%
# 25) What is List? How will you reverse a list?
my_list = [1,2,3]
print(my_list[::-1])
# Out:
# [3, 2, 1]

# %%
# 26) How will you remove last object from a list?
list_of_vowels = ['a', 'e', 'i', 'o', 'u']
list_of_vowels.pop()
# Out:
# 'u'

# %%
# 27) Suppose list1 is [2, 33, 222, 14, and 25], what is list1 [-1]?
list1 = [ 2, 33, 222, 14, 25]
list1[-1]
# Out:
# 25

# %%
# 28) Differentiate between append () and extend () methods?
list1 = [1,2,3]
list1.append([4,5])
list1.extend([4,5])
print(list1)
# Out:
# [1, 2, 3, [4, 5], 4, 5]

# %%
#  29) Write a Python function to get the largest number, smallest num and sum of all from a list.
nums = [10,5,20,8,3]
largest,smallest,total = list_stats(nums)

print("Largest:",largest)
print("Smallest:",smallest)
print("Total Sum:",total)
# Out:
# Largest: 20
# Smallest: 3
# Total Sum: 46

# %%
# 30) How will you compare two lists?
list1 = [1,2,3]
list2 = [1,2,3]
print(list1 == list2)
# Out:
# True

# %%
# 31) Write a Python program to count the number of strings where the string
length is 2 or more and the first and last character are same from a given list
of strings.
words = ['abc','xyz','aba','1221','aa','x']
result = count_matching_strings(words)
print("count:",result)
# Out:
# count: 3

# %%
# 32) Write a Python program to remove duplicates from a list.

def remove_duplicates(lst):
    return list(dict.fromkeys(lst))

nums = [1,2,2,3,3,4,5,5,6]
print(remove_duplicates(nums))
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# 33) Write a Python program to check a list is empty or not.
my_list = []

if not my_list:
  print("The list is empty")
else:
  print("The list is not empty")
# Out:
# The list is empty

# %%
# 34) Write a Python function that takes two lists and returns true if they have at least one common member.
list1 = [1,2,3,4,5]
list2 = [5,6,7,8,9]
for x in list1:
  for y in list2:
    if x == y:
      print("True")
# Out:
# True

# %%
print(have_common_member(list1,list2))
# Out:
# True

# %%
# 35) Write a Python program to generate and print a list of first and last 5 elements where the values are square of numbers between 1 and 30.

# generate list of squares from 1 to 30
square = [i**2 for i in range(1,31)]

# print first 5 elements
print("First 5 elements:", square[:5])

# print last 5 elements
print("last 5 elements:", square[-5:])
# Out:
# First 5 elements: [1, 4, 9, 16, 25]
# last 5 elements: [676, 729, 784, 841, 900]

# %%
# 36) Write a Python function that takes a list and returns a new list with
# unique elements of the first list.
def unique_list(lst):
    return list(dict.fromkeys(lst))

numbers = [1,2,2,3,3,4,5]
print(unique_list(numbers))
# Out:
# [1, 2, 3, 4, 5]

# %%
# 37) Write a Python program to convert a list of characters into a string.

char_list = ['H','e','l','l','o']
result = ''.join(char_list)
print(result)
# Out:
# Hello

# %%
# 38) Write a Python program to select an item randomly from a list.

import random

items =[10,20,30,40,50]
random_item = random.choice(items)
print("Randomly selected item:",random_item)
# Out:
# Randomly selected item: 10

# %%
# 39) Write a Python program to find the second smallest number in a list.

numbers = [10,5,8,3,12]
unique_numbers = list(set(numbers))
unique_numbers.sort()
if len(unique_numbers) >= 2:
  print("Second smallest number:",unique_numbers[1])
else:
  print("List does not have enough unique elemnts.")
# Out:
# Second smallest number: 5

# %%
# 40) Write a Python program to get unique values from a list

numbers = [1,2,2,3,4,4,5]
unique_values = list(set(numbers))
print("Unique values:",unique_values)
# Out:
# Unique values: [1, 2, 3, 4, 5]

# %%
# 41) Write a Python program to check whether a list contains a sub list

list = ['a','x',[1,3,4,5,'hemant']]

for i in list:
    if len(i) > 1:
       print("sublist is present in list")
       break
else:
    print("sublist is not present in list")
# Out:
# sublist is present in list

# %%
# 42) Write a Python program to split a list into different variables.

my_list = [10,20,30]
my_list = a,b,c
print ("a=",a)
print ("b=",b)
print ("c=",c)
# Out:
# a= 10
# b= 20
# c= 30

# %%
# 43) What is tuple? Difference between list and tuple.
A tuple is collection of items in python that is:
- ordered (elements have a fixed postion )
- Immutable (cannot be changed after creation)
- Allows duplicate values
- Written using parentheses ()

# %%
#Difference between list and tuple.

  Feature           List                                          Tuple

 Syntax             [ ]                                             ( )
 Mutability    Mutable (can be changed)                      Immutable (cannot be changed)
 Performance   Slower                                        Faster
 Memory Usage  Uses more memory                              Uses less memory
 Methods       Many built-in methods (append, remove, etc.)  Fewer methods
 Use Case      Used when data may change                     Used when data should not change

# %%
# 44) Write a Python program to create a tuple with different data types.

my_tuple = (10,3.14,"Python",True, [1,2,3])
print("tuple with different data types:")
print(my_tuple)
# Out:
# tuple with different data types:
# (10, 3.14, 'Python', True, [1, 2, 3])

# %%
# 45) Write a Python program to unzip a list of tuples into individual lists.

data = [(1,'abc'),(2,'bcd'),(3,'cde')]

list1 = []
list2 = []

for i in data:
  list1.append(i[0])
  list2.append(i[1])

print(list1)
print(list2)
# Out:
# [1, 2, 3]
# ['abc', 'bcd', 'cde']

# %%
# 46) Write a Python program to convert a list of tuples into a dictionary.

list_of_tuples = [('a',10),('b',20),('c',30)]
result_dict = dict(list_of_tuples)
print(result_dict)
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %%
# 47) How will you create a dictionary using tuples in python?

data = [('a',10),('b',20),('c',30)]
my_dict = dict(data)
print(my_dict)
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %%
# 48) Write a Python script to sort (ascending and descending) a dictionary by value.

my_dict = {'apple' : 50, 'banana' : 20, 'orange' : 30}
ascending = dict(sorted(my_dict.items(), key=lambda item: item[1]))
descending = dict(sorted(my_dict.items(), key=lambda item: item[1], reverse=True))
print("Ascending order:",ascending)
print("Descending order:",descending)
# Out:
# Ascending order: {'banana': 20, 'orange': 30, 'apple': 50}
# Descending order: {'apple': 50, 'orange': 30, 'banana': 20}

# %%
# 49) Write a Python script to concatenate following dictionaries to create a new one.

dict1 = {'a' : 1,'b' : 2}
dict2 = {'c' : 3,'d' : 4}
dict3 = {'e' : 5,'f': 6}
new_dict = {}
new_dict.update(dict1)
new_dict.update(dict2)
new_dict.update(dict3)
print(new_dict)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5, 'f': 6}

# %%
# 50) Write a Python script to check if a given key already exists in a dictionary.

my_dict = {'name':'Priya','age':31,'city':'surat'}
key = 'name'
if key in my_dict:
  print("Key already exists")
else:
  print("Key does not exist")
# Out:
# Key already exists

# %%
# 51) How Do You Traverse Through a Dictionary Object in Python?

my_dict = {'name':'Priya','age':31,'city':'surat'}

for key in my_dict:
  print(key)
for value in my_dict:
  print(value)
for key,value in my_dict.items():
  print(key,value)
# Out:
# name
# age
# city
# name
# age
# city
# name Priya
# age 31
# city surat

# %%
# 52) How Do You Check the Presence of a Key in A Dictionary?

my_dict = {'name':'Priya','age':31,'city':'surat'}
if 'age' in my_dict:
  print("key is present")
else:
  print("key is not present")
if my_dict.get('age') is not  None:
  print("key is present")
# Out:
# key is present
# key is present

# %%
# 53) Write a Python script to print a dictionary where the keys are numbers between 1 and 15.

my_dict = {}

for i in range(1,16):
  my_dict[i] = i * i
print(my_dict)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196, 15: 225}

# %%
# 54) Write a Python program to check multiple keys exists in a dictionary

my_dict = {'name':'Priya','age':31,'city':'surat'}
keys = ["name","age","city"]
if all(key in my_dict for key in keys):
  print("Multiple keys exist")
else:
  print("Multiple keys do not exist")
# Out:
# Multiple keys exist

# %%
# 55) Write a Python script to merge two Python dictionaries

dict1 = {"a":10,"b":20}
dict2 = {"c":30,"d":40}

dict1.update(dict2)
print(dict1)
# Out:
# {'a': 10, 'b': 20, 'c': 30, 'd': 40}

# %%
# 56) Write a Python program to map two lists into a dictionary Sample output: Counter ({'a': 400, 'b': 400,’d’: 400, 'c': 300}).


keys = ['a','b','c','d']
values = [400,400,300,400]
result = (dict(zip(keys,values)))
print(result)
# Out:
# {'a': 400, 'b': 400, 'c': 300, 'd': 400}

# %%
# 57) Write a Python program to find the highest 3 values in a dictionary

my_dict = {'a': 100,'b' : 450,"c" : 300,"d" : 700,"e" : 250}
highest_values = sorted(my_dict.values(),reverse=True)[:3]
print(highest_values)
# Out:
# [700, 450, 300]

# %%
# 58) Write a Python program to combine values in python list of dictionaries.
# Sample data: [{'item': 'item1', 'amount': 400}, {'item': 'item2', 'amount': 300}, {'item': 'item1', 'amount': 750}]
# Expected Output: Counter ({'item1': 1150, 'item2': 300})

from collections import Counter

data = [{'item': 'item1', 'amount': 400}, {'item': 'item2', 'amount': 300}, {'item': 'item1', 'amount': 750}]
result = Counter()

for d in data:
  result[d['item']]+=d['amount']

print(result)
# Out:
# Counter({'item1': 1150, 'item2': 300})

# %%
# 59) Write a Python program to create a dictionary from a string.
# Note: Track the count of the letters from the string.

from collections import Counter

text = "Pythonprogramming"

result = Counter(text)

print(result)
# Out:
# Counter({'o': 2, 'n': 2, 'r': 2, 'g': 2, 'm': 2, 'P': 1, 'y': 1, 't': 1, 'h': 1, 'p': 1, 'a': 1, 'i': 1})

# %%
# 60) Sample string:  'w3resource' Expected output: • {'3': 1,’s’: 1, 'r': 2, 'u': 1, 'w': 1, 'c': 1, 'e': 2, 'o': 1}

sample_string = 'w3resource'
char_count = {}

for ch in sample_string:
  char_count[ch] = char_count.get(ch,0) + 1
print(char_count)
# Out:
# {'w': 1, '3': 1, 'r': 2, 'e': 2, 's': 1, 'o': 1, 'u': 1, 'c': 1}

# %%
# 61) Write a Python function to calculate the factorial of a number (a nonnegative integer)

def factorial(n):
    if n < 0:
     return "Factorial not defined for negative numbers"
    result = 1
    for i in range(1,n+1):
      result *= i
    return result

print(factorial(5))
# Out:
# 120

# %%
# 62) Write a Python function to check whether a number is in a given range

def is_in_range(num,start,end):
  return start <= num <= end
print(is_in_range(5,1,10))
# Out:
# True

# %%
# 63) Write a Python function to check whether a number is perfect or not.

def is_perfect(num):
  if num <= 0:
    return False # Corrected 'false' to 'False'

  total = 0
  for i in range(1, num):
    if num % i == 0:
      total += i # Corrected indentation

  return total == num # Corrected indentation

print(is_perfect(6))
print(is_perfect(10))
# Out:
#   File "<tokenize>", line 12
#     return total == num
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
# 64) Write a Python function that checks whether a passed string is palindrome or not

def is_palindrome(s):
  return s == s[::-1]
print(is_palindrome("madam"))
print(is_palindrome("python"))
# Out:
# True
# False

# %%
# 65) How Many Basic Types of Functions Are Available in Python?

print()
len()
type()
sum()
max()

# %%
# 66) How can you pick a random item from a list or tuple?

import random

items = [10,20,30,40,50]
random_item = random.choice(items)
print(random_item)
# Out:
# 30

# %%
# 67) How can you pick a random item from a range?

import random

num = random.randrange(1,10)
print(num)
# Out:
# 6

# %%
# 68) How can you get a random number in python?

import random
random.randint(1,100)
# Out:
# 30

# %%
# 69) How will you set the starting value in generating random numbers?

import random
random.seed(10)
print(random.randint(1, 100))
print(random.randint(1, 100))
# Out:
# 74
# 5

# %%
# 70) How will you randomize the items of a list in place?

import random
items = [1,2,3.4,5]
random.shuffle(items)
print(items)
# Out:
# [3.4, 1, 2, 5]

# %%
# 71) What is File function in python? What are keywords to create and write file.

In python, the file function mainly refers to the built in open() function. It is used to create,open,read,write,and append files.

 Mode    Description
 ------  --------------------------------------------------------------- |
 `'w'`   Write mode – creates a new file or **overwrites** existing file
 `'a'`   Append mode – creates file if not exists, writes at end
 `'x'`   Exclusive creation – creates file, error if file exists
 `'w+'`  Write + Read mode
 `'a+'`  Append + Read mode

# %%
# 72) Write a Python program to read an entire text file.

file = open("data.txt","r")
content = file.read()
print(content)
file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1369955722.py in <cell line: 0>()
#       1 # 72) Write a Python program to read an entire text file.
#       2
# ----> 3 file = open("data.txt","r")
#       4 content = file.read()
#       5 print(content)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.txt'

# %%
# 73) Write a Python program to append text to a file and display the text.

with open("data.txt","a") as file:
  file.write("\nThis text is appended")
with open("data.txt","r") as file:
  content = file.read()
  print(content)
# Out:
# This text is appended

# %%
# 74) Write a Python program to read first n lines of a file.

n = 3
with open ("data.txt","r") as file:
  for i in range(n):
    line = file.readline()
    if not line:
      break
    print(line,end="")
# Out:
# This text is appended

# %%
# 75) Write a Python program to read last n lines of a file.

n = 3
with open ("data.txt","r") as file:
  lines = file.readlines()
  for line in lines[-n:]:
    print(line, end="")
# Out:
# This text is appended

# %%
# 76) Write a Python program to read a file line by line and store it into a list

with open ("data.txt","r") as file:
  lines_list = file.readlines()
print(lines_list)
# Out:
# ['\n', 'This text is appended']

# %%
# 77) Write a Python program to read a file line by line store it into a variable.

content = ""
with open("data.txt","r") as file:
  for line in file:
    content += line
print(content)
# Out:
# This text is appended

# %%
# 78) Write a python program to find the longest words.

with open("data.txt","r") as file:
  words = file.read().split()
max_length = max(len(word)for word in words)
longest_words = [word for word in words if len(word) == max_length]
print("Longest word length:",max_length)
print("Longest word(s):",longest_words)
# Out:
# Longest word length: 8
# Longest word(s): ['appended']

# %%
# 79) Write a Python program to count the number of lines in a text file.

count = 0
with open("data.txt","r") as file:
   for line in file:
     count += 1
print("Number of lines:",count)
# Out:
# Number of lines: 2

# %%
# 80) Write a Python program to count the frequency of words in a file.

word_count = {}

with open("data.txt","r")as file:
  for line in file:
    words = line.split()
    for word in words:
      word = word.lower()
      word_count[word] = word_count.get(word,0)+1

  print(word_count)
# Out:
# {'this': 1, 'text': 1, 'is': 1, 'appended': 1}

# %%
# 81) Write a Python program to write a list to a file.

my_list = [1,2,3,4,5]

with open("data.txt","w") as file:
  for item in my_list:
    file.write(str(item) + "\n")

# %%
# 82) Write a Python program to copy the contents of a file to another file.

# Create a dummy source.txt file for demonstration purposes
with open("source.txt", "w") as f:
    f.write("This is some content from the source file.")

with open ("source.txt","r") as src:
    data = src.read()
with open ("destination.txt","w") as dest:
    dest.write(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2185196355.py in <cell line: 0>()
#       1 # 82) Write a Python program to copy the contents of a file to another file.
#       2
# ----> 3 with open ("source.txt","r") as src:
#       4     data = src.read()
#       5 with open ("destination.txt","r") as dest:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'source.txt'

# %%
# 83) Explain Exception handling? What is an Error in Python?

Exception handling is a mechanism used to handle runtime errors so that the normal flow of a program is not interrupted

- An Error is a serious issue that occurs when the program cannot be executed or continued.
1)Syntax Error
2)Runtime Error
3)Logical Error

# %%
# 84) How many except statements can a try-except block have? Name Some built-in exception classes:
# A try-except block can have multiple except statements.
# Some built-in exception classes: ValueError, ZeroDivisionError, TypeError, IndexError, FileNotFoundError.

try:
  x = int(input("Enter a number"))
  y = 10 / x

except ValueError:
  print("Invalid input")
except ZeroDivisionError:
  print("Cannot divide by zero")
except Exception as e: # Catch any other unexpected errors
  print(f"An error occurred: {e}")
# Out:
#   File "/tmp/ipython-input-2197529500.py", line 9
#     excepgt ZeroDivisionError:
#             ^
# SyntaxError: invalid syntax

# %%
# 85) When will the else part of try-except-else be executed?

try:
  x = int(input("Enter a number"))
  result = 10/x
except ZeroDivisionError:
  print("Cannot divide by zero")
except ValueError:
  print("Invalid input")
else:
  print("Result is:",result)

# %%
# 86) Can one block of except statements handle multiple exception?

try :
  a = int(input("Enter a number"))
  b = int(input("Enter another number: "))
  print(a/b)

except(ValueError, ZeroDivisionError):
  print("Invalid input or division by zero error")
# Out:
# Enter another number: 10
# 1.0

# %%
# 87) When is the finally block executed?

try
   x = 10 / 2
   print(x)
except ZeroDivisionError:
   print("Error: Division by zero")
finally:
   print("This is finally block")

# %%
# 88) What happens when „1‟== 1 is executed?

print(int('1') == 1)

# %%
# 89) How Do You Handle Exceptions with Try/Except/Finally in Python? Explain with coding snippets.

try :
  x = 10 / 0
except ZeroDivisionError:
  print("Division by zero is not allowed")

# %%
# 90) Write python program that user to enter only odd numbers, else will raise an exception.

try:
  num = int(input("Enter an odd number: "))

  if num % 2 == 0:
    raise ValueError("Even numbeR entered")

  print("You entered a valid odd number:",num)
except ValueError as e:
  print("Excepted:", e)
# Out:
# Enter an odd number: 10
# Excepted: Even numbeR entered
